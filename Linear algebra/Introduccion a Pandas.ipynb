# %%
import pandas as pd

# %%
# Para leer un numero de columnas filas concretas
#df = pd.read_csv("csv_examples/prueba1_pandas.csv", nrows=5)
# Para leer todo el documento completo
df = pd.read_csv("csv_examples/prueba1_pandas.csv")

# %%
# Viendo los primeros 2 registros
df.head(2)
# Out:
#    id        nombre  num_a  num_b  num_c  num_d
# 0   1  pruebanombre     10    524      1   6390
# 1   2  pruebanombre     10    525      1   7080

# %%
# Viendo los 4 ultimos registros
df.tail(4)
# Out:
#      id        nombre  num_a  num_b  num_c  num_d
# 62  216  pruebanombre     10    732      1   1062
# 63  217  pruebanombre     10    733      1  12640
# 64  218  pruebanombre     11    317      1   2460
# 65  219  pruebanombre     11    558      1  15840

# %%
# Viendo las columnas
df.columns
# Out:
# Index(['id', 'nombre', 'num_a', 'num_b', 'num_c', 'num_d'], dtype='object')

# %%
# Viendo los tipos de datos de las columnas
df.dtypes
# Out:
# id         int64
# nombre    object
# num_a      int64
# num_b      int64
# num_c      int64
# num_d      int64
# dtype: object

# %%
# Obteniendo los datos en array
df.values
# Out:
# array([[1, 'pruebanombre', 10, 524, 1, 6390],
#        [2, 'pruebanombre', 10, 525, 1, 7080],
#        [3, 'pruebanombre', 11, 558, 1, 15840],
#        [4, 'pruebanombre', 11, 621, 1, 7300],
#        [8, 'pruebanombre', 10, 524, 1, 6390],
#        [9, 'pruebanombre', 10, 525, 2, 7080],
#        [10, 'pruebanombre', 11, 558, 1, 15840],
#        [11, 'pruebanombre', 11, 621, 1, 7300],
#        [12, 'pruebanombre', 10, 524, 1, 6390],
#        [13, 'pruebanombre', 10, 525, 2, 7080],
#        [14, 'pruebanombre', 11, 558, 1, 15840],
#        [15, 'pruebanombre', 11, 621, 1, 7300],
#        [16, 'pruebanombre', 10, 524, 1, 6390],
#        [17, 'pruebanombre', 10, 525, 2, 7080],
#        [18, 'pruebanombre', 11, 558, 1, 15840],
#        [19, 'pruebanombre', 11, 621, 1, 7300],
#        [20, 'pruebanombre', 10, 524, 1, 6390],
#        [21, 'pruebanombre', 10, 525, 2, 7080],
#        [22, 'pruebanombre', 11, 558, 1, 15840],
#        [23, 'pruebanombre', 11, 621, 1, 7300],
# ...

# %%
# Filtrado por columnas
df['nombre'][0:8]
# Out:
# 0    pruebanombre
# 1    pruebanombre
# 2    pruebanombre
# 3    pruebanombre
# 4    pruebanombre
# 5    pruebanombre
# 6    pruebanombre
# 7    pruebanombre
# Name: nombre, dtype: object

# %%
# Filtrando por condicion
df[df['id'] > 30]
# Out:
#      id        nombre  num_a  num_b  num_c  num_d
# 27   31  pruebanombre     11    621      1   7300
# 28   52  pruebanombre     10    524      1   6390
# 29   53  pruebanombre     10    525      2   7080
# 30   54  pruebanombre     11    558      1  15840
# 31   55  pruebanombre     11    621      1   7300
# 32   56  pruebanombre     10    524      1   6390
# 33   57  pruebanombre     10    525      2   7080
# 34   58  pruebanombre     11    558      1  15840
# 35   59  pruebanombre     11    621      1   7300
# 36   68  pruebanombre     10    524      1   6390
# 37   69  pruebanombre     10    525      2   7080
# 38   70  pruebanombre     11    558      1  15840
# 39   71  pruebanombre     11    621      1   7300
# 40   72  pruebanombre     10    524      1   6390
# 41   73  pruebanombre     10    525      2   7080
# 42   74  pruebanombre     11    558      1  15840
# 43   75  pruebanombre     11    621      1   7300
# 44   81  pruebanombre     10    524      3   6390
# ...
